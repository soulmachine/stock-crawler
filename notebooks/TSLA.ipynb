# %% [markdown]
# # Explore Tesla Options Data

# %%
from typing import Dict, List, Tuple

import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ## Available Calls on 2022-05-20

# %%
tsla = pd.read_csv('../data/options/TSLA/summary/calls-2022-05-20.csv.xz')

# %%
tsla_calls = tsla[tsla['inTheMoney']]

# %%
tsla_calls
# Out:
#          contractSymbol              lastTradeDate  strike  lastPrice  \
# 0   TSLA220520C00050000  2021-12-29 15:04:49+00:00    50.0    1026.00
# 1   TSLA220520C00100000  2022-01-04 18:08:53+00:00   100.0    1064.92
# 2   TSLA220520C00150000  2022-01-05 18:25:24+00:00   150.0     989.78
# 3   TSLA220520C00200000  2021-12-10 15:29:42+00:00   200.0     801.15
# 4   TSLA220520C00250000  2021-11-05 19:04:27+00:00   250.0     977.65
# 5   TSLA220520C00300000  2022-01-05 18:25:24+00:00   300.0     840.90
# 6   TSLA220520C00350000  2021-10-29 14:28:08+00:00   350.0     746.20
# 7   TSLA220520C00360000  2021-11-22 18:56:55+00:00   360.0     814.10
# 8   TSLA220520C00370000  2021-12-01 20:00:10+00:00   370.0     757.60
# 9   TSLA220520C00380000  2021-11-03 14:09:19+00:00   380.0     800.49
# 10  TSLA220520C00390000  2022-01-04 15:01:55+00:00   390.0     796.85
# 11  TSLA220520C00400000  2021-12-10 15:55:18+00:00   400.0     600.80
# ...

# %% [markdown]
# ## Available Puts on 2022-05-20

# %%
tsla = pd.read_csv('../data/options/TSLA/summary/puts-2022-05-20.csv.xz')

# %%
tsla_puts = tsla[tsla['inTheMoney']]

# %%
tsla_puts
# Out:
#           contractSymbol              lastTradeDate  strike  lastPrice  \
# 48   TSLA220520P00770000  2022-01-05 20:03:36+00:00   770.0      36.62
# 49   TSLA220520P00780000  2022-01-05 20:53:56+00:00   780.0      40.10
# 50   TSLA220520P00790000  2022-01-05 16:23:22+00:00   790.0      35.30
# 51   TSLA220520P00800000  2022-01-05 20:49:08+00:00   800.0      45.30
# 52   TSLA220520P00810000  2022-01-05 20:03:36+00:00   810.0      45.92
# ..                   ...                        ...     ...        ...
# 114  TSLA220520P02175000  2021-11-30 16:37:13+00:00  2175.0    1064.65
# 115  TSLA220520P02200000  2021-11-30 17:35:17+00:00  2200.0    1082.60
# 116  TSLA220520P02225000  2021-12-01 15:39:58+00:00  2225.0    1092.00
# 117  TSLA220520P02250000  2021-12-01 15:39:58+00:00  2250.0    1116.00
# 118  TSLA220520P02275000  2021-12-01 15:39:58+00:00  2275.0    1140.15
#
#          bid      ask    change  percentChange  volume  openInterest  \
# ...

# %% [markdown]
# ## Plot the Price of TSLA May 20 '22 750.00 Call

# %%
df = pd.read_csv('../data/options/TSLA/history/TSLA220520C00750000.csv.xz', index_col='Date', parse_dates=['Date'])

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.lineplot(x=df.index, y=df['Close'], ax=ax).set_title('Close Price of TSLA May 20 \'22 750.00 Call')
# Out:
# Text(0.5, 1.0, "Close Price of TSLA May 20 '22 750.00 Call")

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.lineplot(data=df[['Open', 'High', 'Low', 'Close']])
# Out:
# <AxesSubplot:xlabel='Date'>
